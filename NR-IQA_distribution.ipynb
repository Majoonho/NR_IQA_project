# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/drive/MyDrive/기업연계프로젝트/NRIQA_df_testset_all.csv")

# %%
data
# Out:
#       CPBD    NIQE  BRISQUE  CNNIQA  ILNIQE   HYPER  WaDIQaM_LIVE  DIQaM_LIVE  \
# 0    0.110  16.514   55.632  27.304  47.736  49.708         0.672      14.822
# 1    0.070  13.555   58.664  28.134  48.985  36.220         0.146       4.172
# 2    0.054  13.429   59.210  29.553  47.442  50.365        27.355      17.135
# 3    0.073  13.518   59.874  29.035  47.185  45.570        13.194      16.671
# 4    0.056  13.177   59.195  29.045  47.229  43.568        26.081      24.954
# ..     ...     ...      ...     ...     ...     ...           ...         ...
# 995  0.512  37.663   82.061  74.090  75.053  41.711        20.647      18.844
# 996  0.454  31.211   84.039  72.982  67.811  37.756        13.261      16.202
# 997  0.423  27.146   85.132  73.787  70.940  24.275        53.529      56.328
# 998  0.429  26.361   84.892  73.292  69.478  39.504        24.302      16.750
# 999  0.487  23.771   84.595  74.676  68.416  32.534        47.484      11.924
#
# ...

# %%
columns = data.columns

# %%
columns
# Out:
# Index(['CPBD', 'NIQE', 'BRISQUE', 'CNNIQA', 'ILNIQE', 'HYPER', 'WaDIQaM_LIVE',
#        'DIQaM_LIVE', 'WaDIQaM_TID', 'DIQaM_TID', 'DIST'],
#       dtype='object')

# %%
for col in columns[:-1]:
    plt.figure()
    sns.kdeplot(data = data,x=col,  hue = "DIST")
    plt.show()

# %%
df = pd.read_csv("/content/drive/MyDrive/기업연계프로젝트/NR_testset_all.csv")

# %%
df
# Out:
#       CPBD  BRISQUE  CNNIQA   HYPER  WaDIQaM_LIVE  DIQaM_LIVE  WaDIQaM_TID  \
# 0    0.071   48.724  28.515  38.290        44.137      27.459       65.401
# 1    0.090   55.511  26.866  38.343        40.939      30.512       43.843
# 2    0.033   57.099  33.209  38.969        48.081      30.675       59.146
# 3    0.540   56.827  11.879  32.192        24.894      48.398       36.710
# 4    0.614   56.514  12.049  46.201        13.249      13.857       33.299
# ..     ...      ...     ...     ...           ...         ...          ...
# 995  0.138   39.468  21.051  43.257        33.068      24.834       35.244
# 996  0.104   35.620  35.111  49.348        38.789      39.212       86.420
# 997  0.060   36.593  40.958  49.014        43.411      39.458       88.952
# 998  0.522   73.660  45.765  24.702        41.598      35.230       53.968
# 999  0.532   42.804  46.117  29.768        48.603      29.935       50.670
#
#      DIQaM_TID  DIST  NR_result
# 0       40.044  high   2.596959
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.columns
# Out:
# Index(['CPBD', 'BRISQUE', 'CNNIQA', 'HYPER', 'WaDIQaM_LIVE', 'DIQaM_LIVE',
#        'WaDIQaM_TID', 'DIQaM_TID', 'DIST', 'NR_result'],
#       dtype='object')

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[0],  hue = "DIST")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[1],  hue = "DIST")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[2],  hue = "DIST")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[3],  hue = "DIST")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[4],  hue = "DIST")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[5],  hue = "DIST")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[6],  hue = "DIST")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[7],  hue = "DIST")
plt.show()

# %%
df = pd.read_csv("/content/drive/MyDrive/기업연계프로젝트/NRIQA_df_ffhq_all.csv")

# %%
df
# Out:
#         CPBD    NIQE  BRISQUE  CNNIQA   HYPER  WaDIQaM_LIVE  DIQaM_LIVE  \
# 0      0.035  14.864   76.643  61.500  74.136        69.789      71.897
# 1      0.234  14.790   56.684  47.998  72.220        59.054      59.304
# 2      0.440  11.608   15.740  16.397  62.942        71.219      65.756
# 3      0.000  17.399   95.894  77.725  45.001        21.404      23.330
# 4      0.611   7.479   -3.795  13.307  40.148        59.486      58.296
# ...      ...     ...      ...     ...     ...           ...         ...
# 17995  0.107  15.047   42.040  31.115  36.929        33.049      34.518
# 17996  0.120  15.777   35.979  44.116  55.365        25.978      29.403
# 17997  0.267  16.676   52.026  28.585  55.797        27.556      31.386
# 17998  0.584  15.056   13.213  22.878  60.382        29.265      26.997
# 17999  0.547  16.746   30.659  29.183  66.139        50.743      35.381
#
#        WaDIQaM_TID  DIQaM_TID  DIST_SORT DIST_RATE        DIST_IMG
# ...

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[0],  hue = "DIST_RATE")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[1],  hue = "DIST_RATE")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[2],  hue = "DIST_RATE")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[3],  hue = "DIST_RATE")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[4],  hue = "DIST_RATE")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[5],  hue = "DIST_RATE")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[6],  hue = "DIST_RATE")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[7],  hue = "DIST_RATE")
plt.show()

# %%
df = pd.read_csv("/content/drive/MyDrive/기업연계프로젝트/NRIQA_df_last.csv")

# %%
df
# Out:
#        CPBD    NIQE  BRISQUE  CNNIQA  ILNIQE   HYPER  WaDIQaM_LIVE  \
# 0     0.524  15.288   18.468  17.725  22.025  67.377         7.515
# 1     0.407  16.106   26.225  21.482  24.490  59.614        26.515
# 2     0.131  18.836   50.731  43.691  36.201  42.574        44.362
# 3     0.005  18.813   70.424  61.468  59.741  38.503        56.649
# 4     0.000  17.540   90.263  78.708  90.068  43.387        52.663
# ...     ...     ...      ...     ...     ...     ...           ...
# 1210  0.586   9.889    1.867  24.134  28.267  64.626        50.081
# 1211  0.430  16.853   14.119  31.408  28.785  52.423        44.000
# 1212  0.472  20.821   28.383  40.116  35.516  40.440        48.820
# 1213  0.104  18.558   54.815  41.899  47.930  34.846        54.851
# 1214  0.073  19.634   25.641  46.625  47.633  31.975        45.720
#
#       DIQaM_LIVE  WaDIQaM_TID  DIQaM_TID  DMOS       DIST_IMG  level
# 0         29.026       34.108     35.453  4.57  I01_01_01.png      1
# ...

# %%
df["level"] = [i%5 + 1 for i in range(1215)]

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[0],  hue = "level")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[1],  hue = "level")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[2],  hue = "level")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[3],  hue = "level")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[4],  hue = "level")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[5],  hue = "level")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[6],  hue = "level")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[7],  hue = "level")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[8],  hue = "level")
plt.show()

# %%
plt.figure()
sns.kdeplot(data = df,x=df.columns[9],  hue = "level")
plt.show()
